# %% [markdown]
# ## API Key Configuration
#
# The following cell configures the Electricity Maps API key required to run the scripts that download data from the API.

# %%
import os

os.environ["ELECTRICITY_MAPS_API_KEY"] = "patCytbSzwwY9ZZhgner"

# %% [markdown]
# ## Final Project Group 2 - RENEWABLE GENERATION
# _Objective: Analyze renewable energy penetration in Europe._

# %% [markdown]
# ### Hydro Generation

# %%
# %run Hydro_global_3_countries.py
# Out:
# Hydro statistics :
# country  average_hydro_generation_gw  maximum_hydro_generation_gw  minimum_hydro_generation_gw  hydro_generation_std_gw
#      DE                     1.222068                        2.433                        0.746                 0.277954
#      ES                     5.034907                        8.924                        0.949                 2.014975
#      FR                     7.555531                       11.540                        2.679                 1.600384

# %% [markdown]
# France appears to be leading the way in hydro generation as it has the highest average, maximum and minimum values of hydro generation.
# Hydro generation seems marginal in Germany.

# %%
# %run Hydro_daily_generation_3_countries.py

# %% [markdown]
# The previous graph displays daily hydroelectricity generation in gigawatt-hours per day (GWh/day) for France, Spain and Germany.
#
# France generates the most hydroelectric power among the three countries, with outputs ranging from 100 to over 200 GWh/day. There are noticeable peaks throughout the period but despite those fluctuations, France maintains a strong and consistent hydroelectric output.
# Spain’s hydroelectric generation typically ranges between 50 to 160 GWh/day and appears as more dependent on seasonal change. Indeed, there is a clear upward trend from early January to mid-to-late March.
# Germany has the lowest hydroelectric generation, mostly staying within 20 to 80 GWh/day.

# %%
# %run Hydro_hourly_generation_3_countries.py

# %% [markdown]
# The hourly hydro electricity generation for those three countries was also studied.
#
# In France, the daily generation of hydro electricity has two peaks : one at 7AM-8AM and the other at 18AM which illustrates how France adapts their hydro production to their demand. Spain has one peak toward the end of the day which also reflect a clear managment of the generation linked to the demand profile. Germany has little production that variate in lesser proportion throughout the day.

# %%
# %run wind_analysis.py
# Out:
# Loading data for FR (France)...
#   Fetching 2026-01-01 → 2026-01-08... ✓ 168 records
#   Fetching 2026-01-08 → 2026-01-15... ✓ 168 records
#   Fetching 2026-01-15 → 2026-01-22... ✓ 168 records
#   Fetching 2026-01-22 → 2026-01-29... ✓ 168 records
#   Fetching 2026-01-29 → 2026-02-05... ✓ 168 records
#   Fetching 2026-02-05 → 2026-02-12... ✓ 168 records
#   Fetching 2026-02-12 → 2026-02-19... ✓ 168 records
#   Fetching 2026-02-19 → 2026-02-26... ✓ 168 records
#   Fetching 2026-02-26 → 2026-03-05... ✓ 168 records
#   Fetching 2026-03-05 → 2026-03-12... ✓ 168 records
#   Fetching 2026-03-12 → 2026-03-19... ✓ 168 records
#   Fetching 2026-03-19 → 2026-03-26... ✓ 168 records
#   Fetching 2026-03-26 → 2026-04-01... ✓ 144 records
#   Total: 2160 hourly records for France.
#   2160 data points loaded.
#
# Loading data for ES (Spain)...
#   Fetching 2026-01-01 → 2026-01-08... ✓ 168 records
#   Fetching 2026-01-08 → 2026-01-15... ✓ 168 records
# ...

# %% [markdown]
# ## Solar Generation
#
# This section analyses hourly solar generation in Spain, France and Germany from January to March 2026 using the Electricity Maps API.
#
# The analysis compares the three countries through hourly solar generation, daily averages, total solar generation and summary statistics.

# %%
# %run Solar_hourly_generation_3_countries_imen.py
# Out:
# ...
# Example API record:
# {'datetime': '2026-01-01T00:00:00.000Z', 'updatedAt': '2026-04-13T14:19:03.761Z', 'estimationMethod': 'MEASURED', 'mix': {'nuclear': 7116, 'geothermal': 0, 'biomass': 620, 'coal': 0, 'wind': 2659, 'solar': 36, 'hydro': 2592, 'gas': 7392, 'oil': 26, 'unknown': 72, 'hydro storage': {'charge': None, 'discharge': 902}, 'battery storage': {'charge': 0, 'discharge': None}, 'flows': {'exports': 572, 'imports': 1717}}}
# ...
# Example API record:
# {'datetime': '2026-01-11T00:00:00.000Z', 'updatedAt': '2026-04-10T04:38:12.498Z', 'estimationMethod': 'MEASURED', 'mix': {'nuclear': 7115, 'geothermal': 0, 'biomass': 571, 'coal': 0, 'wind': 12006, 'solar': 32, 'hydro': 2685, 'gas': 5077, 'oil': 26, 'unknown': 72, 'hydro storage': {'charge': None, 'discharge': 672}, 'battery storage': {'charge': 0, 'discharge': None}, 'flows': {'exports': 4687, 'imports': 153}}}
# ...
# Example API record:
# ...

# %% [markdown]
# ## Energy Mix
#
# This section analyses the electricity mix of Spain, France and Germany using hourly data from January to March 2026.
#
# The script extracts technologies such as solar, wind, hydro, gas, coal, nuclear, biomass, oil and geothermal. It also calculates total generation, renewable generation and renewable share by country.

# %%
# %run Mix_hourly_generation_3_countries.py
# Out:
# ...
#
# First rows of mix data:
#                    datetime country            source  solar    wind   hydro     gas  coal  nuclear  biomass  oil  geothermal  unknown  total_generation_mw  renewable_generation_mw  \
# 0 2026-01-01 00:00:00+00:00      ES  Electricity Maps   36.0 2,659.0 2,592.0 7,392.0   0.0  7,116.0    620.0 26.0         0.0     72.0             20,513.0                  5,907.0
# 1 2026-01-01 01:00:00+00:00      ES  Electricity Maps   36.0 3,223.0 2,312.0 6,456.0   0.0  7,116.0    618.0 28.0         0.0     73.0             19,862.0                  6,189.0
# 2 2026-01-01 02:00:00+00:00      ES  Electricity Maps   36.0 3,319.0 2,422.0 6,037.0   0.0  7,116.0    600.0 28.0         0.0     72.0             19,630.0                  6,377.0
# 3 2026-01-01 03:00:00+00:00      ES  Electricity Maps   36.0 3,704.0 2,398.0 6,032.0   0.0  7,112.0    610.0 25.0         0.0     68.0             19,985.0                  6,748.0
# ...

# %% [markdown]
# ## Renewable Generation and Price Correlation
#
# This section studies the relationship between renewable electricity generation and electricity prices.
#
# The goal is to understand whether higher renewable penetration is associated with changes in electricity market prices in Spain, France and Germany.

# %%
# %run Renewables_price_correlation_3_countries.py
print("Renewable-price correlation script is included in the project, but it currently requires fixing the price API response before execution.")
# Out:
# Renewable-price correlation script is included in the project, but it currently requires fixing the price API response before execution.

# %% [markdown]
# ## Final Conclusions
#
# This project compares renewable electricity generation in Spain, France and Germany using hourly data for the first quarter of 2026.
#
# The hydro, wind, solar and energy mix analyses show that each country has a different renewable generation profile. Solar generation is mainly concentrated during daylight hours, wind generation presents strong variability, and hydro generation contributes differently depending on the country.
#
# The energy mix section provides a broader view of the role of renewable technologies within total electricity generation. The renewable-price correlation section helps connect renewable penetration with electricity market behaviour.
#
# Overall, the project provides a comparative analysis of renewable penetration in three European electricity systems using real data from public energy sources.
